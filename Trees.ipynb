# %%
import numpy as np
import pandas as pd
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier

# %%
train_x, train_y = pd.read_csv('ProcessedData/X_train.csv', index_col=0), pd.read_csv('ProcessedData/Y_train.csv', index_col=False)
test_x, test_y = pd.read_csv('ProcessedData/X_test.csv', index_col=0), pd.read_csv('ProcessedData/Y_test.csv', index_col=False)

# %%
train_x = train_x.to_numpy()
train_y = train_y.to_numpy().flatten()
test_x = test_x.to_numpy()
test_y = test_y.to_numpy().flatten()

train_x, train_y
# Out:
# (array([[ 0.        , -0.05774286,  0.        , ...,  0.        ,
#           0.        ,  1.        ],
#         [ 0.        , -0.8249227 ,  0.        , ...,  0.        ,
#           0.        ,  1.        ],
#         [ 1.        , -0.05774286,  0.        , ...,  1.        ,
#           0.        ,  0.        ],
#         ...,
#         [ 0.        , -0.47620457,  0.        , ...,  0.        ,
#           1.        ,  0.        ],
#         [ 0.        ,  0.36071885,  0.        , ...,  0.        ,
#           0.        ,  1.        ],
#         [ 0.        , -0.05774286,  0.        , ...,  1.        ,
#           0.        ,  0.        ]]),
#  array([0., 0., 1., ..., 0., 0., 0.]))

# %%
import itertools

params = {"n_estimators": [100, 300, 1000], 
          "max_depth": [10, 30, 100],
          "min_samples_split": [2, 5, 10],
          "min_samples_leaf": [10, 30, 100]}

for (n_estimators, max_depth, min_samples_split, min_samples_leaf) in itertools.product(*params.values()):
    model = RandomForestClassifier(n_estimators=n_estimators, max_depth=max_depth, min_samples_split=min_samples_split, min_samples_leaf=min_samples_leaf, random_state=42)
    model.fit(train_x, train_y)
    score = model.score(test_x, test_y)

    print(f"Score: {score}, n_estimators: {n_estimators}, max_depth: {max_depth}, min_samples_split: {min_samples_split}, min_samples_leaf: {min_samples_leaf}")
# Out:
# Score: 0.7906843013225991, n_estimators: 100, max_depth: 10, min_samples_split: 2, min_samples_leaf: 10
# Score: 0.7906843013225991, n_estimators: 100, max_depth: 10, min_samples_split: 2, min_samples_leaf: 30
# Score: 0.7734330074755607, n_estimators: 100, max_depth: 10, min_samples_split: 2, min_samples_leaf: 100
# Score: 0.7906843013225991, n_estimators: 100, max_depth: 10, min_samples_split: 5, min_samples_leaf: 10
# Score: 0.7906843013225991, n_estimators: 100, max_depth: 10, min_samples_split: 5, min_samples_leaf: 30
# Score: 0.7734330074755607, n_estimators: 100, max_depth: 10, min_samples_split: 5, min_samples_leaf: 100
# Score: 0.7906843013225991, n_estimators: 100, max_depth: 10, min_samples_split: 10, min_samples_leaf: 10
# Score: 0.7906843013225991, n_estimators: 100, max_depth: 10, min_samples_split: 10, min_samples_leaf: 30
# Score: 0.7734330074755607, n_estimators: 100, max_depth: 10, min_samples_split: 10, min_samples_leaf: 100
# Score: 0.7906843013225991, n_estimators: 100, max_depth: 30, min_samples_split: 2, min_samples_leaf: 10
# Score: 0.7883841288096607, n_estimators: 100, max_depth: 30, min_samples_split: 2, min_samples_leaf: 30
# Score: 0.7740080506037953, n_estimators: 100, max_depth: 30, min_samples_split: 2, min_samples_leaf: 100
# Score: 0.7906843013225991, n_estimators: 100, max_depth: 30, min_samples_split: 5, min_samples_leaf: 10
# Score: 0.7883841288096607, n_estimators: 100, max_depth: 30, min_samples_split: 5, min_samples_leaf: 30
# Score: 0.7740080506037953, n_estimators: 100, max_depth: 30, min_samples_split: 5, min_samples_leaf: 100
# Score: 0.7906843013225991, n_estimators: 100, max_depth: 30, min_samples_split: 10, min_samples_leaf: 10
# Score: 0.7883841288096607, n_estimators: 100, max_depth: 30, min_samples_split: 10, min_samples_leaf: 30
# Score: 0.7740080506037953, n_estimators: 100, max_depth: 30, min_samples_split: 10, min_samples_leaf: 100
# Score: 0.7906843013225991, n_estimators: 100, max_depth: 100, min_samples_split: 2, min_samples_leaf: 10
# Score: 0.7883841288096607, n_estimators: 100, max_depth: 100, min_samples_split: 2, min_samples_leaf: 30
# Score: 0.7740080506037953, n_estimators: 100, max_depth: 100, min_samples_split: 2, min_samples_leaf: 100
# Score: 0.7906843013225991, n_estimators: 100, max_depth: 100, min_samples_split: 5, min_samples_leaf: 10
# Score: 0.7883841288096607, n_estimators: 100, max_depth: 100, min_samples_split: 5, min_samples_leaf: 30
# Score: 0.7740080506037953, n_estimators: 100, max_depth: 100, min_samples_split: 5, min_samples_leaf: 100
# Score: 0.7906843013225991, n_estimators: 100, max_depth: 100, min_samples_split: 10, min_samples_leaf: 10
# Score: 0.7883841288096607, n_estimators: 100, max_depth: 100, min_samples_split: 10, min_samples_leaf: 30
# Score: 0.7740080506037953, n_estimators: 100, max_depth: 100, min_samples_split: 10, min_samples_leaf: 100
# Score: 0.7901092581943646, n_estimators: 300, max_depth: 10, min_samples_split: 2, min_samples_leaf: 10
# Score: 0.7901092581943646, n_estimators: 300, max_depth: 10, min_samples_split: 2, min_samples_leaf: 30
# Score: 0.7780333525014376, n_estimators: 300, max_depth: 10, min_samples_split: 2, min_samples_leaf: 100
# Score: 0.7901092581943646, n_estimators: 300, max_depth: 10, min_samples_split: 5, min_samples_leaf: 10
# Score: 0.7901092581943646, n_estimators: 300, max_depth: 10, min_samples_split: 5, min_samples_leaf: 30
# Score: 0.7780333525014376, n_estimators: 300, max_depth: 10, min_samples_split: 5, min_samples_leaf: 100
# Score: 0.7901092581943646, n_estimators: 300, max_depth: 10, min_samples_split: 10, min_samples_leaf: 10
# Score: 0.7901092581943646, n_estimators: 300, max_depth: 10, min_samples_split: 10, min_samples_leaf: 30
# Score: 0.7780333525014376, n_estimators: 300, max_depth: 10, min_samples_split: 10, min_samples_leaf: 100
# Score: 0.7929844738355377, n_estimators: 300, max_depth: 30, min_samples_split: 2, min_samples_leaf: 10
# Score: 0.7912593444508338, n_estimators: 300, max_depth: 30, min_samples_split: 2, min_samples_leaf: 30
# Score: 0.7768832662449684, n_estimators: 300, max_depth: 30, min_samples_split: 2, min_samples_leaf: 100
# Score: 0.7929844738355377, n_estimators: 300, max_depth: 30, min_samples_split: 5, min_samples_leaf: 10
# Score: 0.7912593444508338, n_estimators: 300, max_depth: 30, min_samples_split: 5, min_samples_leaf: 30
# Score: 0.7768832662449684, n_estimators: 300, max_depth: 30, min_samples_split: 5, min_samples_leaf: 100
# Score: 0.7929844738355377, n_estimators: 300, max_depth: 30, min_samples_split: 10, min_samples_leaf: 10
# Score: 0.7912593444508338, n_estimators: 300, max_depth: 30, min_samples_split: 10, min_samples_leaf: 30
# Score: 0.7768832662449684, n_estimators: 300, max_depth: 30, min_samples_split: 10, min_samples_leaf: 100
# Score: 0.7929844738355377, n_estimators: 300, max_depth: 100, min_samples_split: 2, min_samples_leaf: 10
# Score: 0.7912593444508338, n_estimators: 300, max_depth: 100, min_samples_split: 2, min_samples_leaf: 30
# Score: 0.7768832662449684, n_estimators: 300, max_depth: 100, min_samples_split: 2, min_samples_leaf: 100
# Score: 0.7929844738355377, n_estimators: 300, max_depth: 100, min_samples_split: 5, min_samples_leaf: 10
# Score: 0.7912593444508338, n_estimators: 300, max_depth: 100, min_samples_split: 5, min_samples_leaf: 30
# Score: 0.7768832662449684, n_estimators: 300, max_depth: 100, min_samples_split: 5, min_samples_leaf: 100
# Score: 0.7929844738355377, n_estimators: 300, max_depth: 100, min_samples_split: 10, min_samples_leaf: 10
# Score: 0.7912593444508338, n_estimators: 300, max_depth: 100, min_samples_split: 10, min_samples_leaf: 30
# Score: 0.7768832662449684, n_estimators: 300, max_depth: 100, min_samples_split: 10, min_samples_leaf: 100
# Score: 0.7901092581943646, n_estimators: 1000, max_depth: 10, min_samples_split: 2, min_samples_leaf: 10
# Score: 0.7901092581943646, n_estimators: 1000, max_depth: 10, min_samples_split: 2, min_samples_leaf: 30
# Score: 0.7751581368602645, n_estimators: 1000, max_depth: 10, min_samples_split: 2, min_samples_leaf: 100
# Score: 0.7901092581943646, n_estimators: 1000, max_depth: 10, min_samples_split: 5, min_samples_leaf: 10
# Score: 0.7901092581943646, n_estimators: 1000, max_depth: 10, min_samples_split: 5, min_samples_leaf: 30
# Score: 0.7751581368602645, n_estimators: 1000, max_depth: 10, min_samples_split: 5, min_samples_leaf: 100
# Score: 0.7901092581943646, n_estimators: 1000, max_depth: 10, min_samples_split: 10, min_samples_leaf: 10
# Score: 0.7901092581943646, n_estimators: 1000, max_depth: 10, min_samples_split: 10, min_samples_leaf: 30
# Score: 0.7751581368602645, n_estimators: 1000, max_depth: 10, min_samples_split: 10, min_samples_leaf: 100
# Score: 0.7906843013225991, n_estimators: 1000, max_depth: 30, min_samples_split: 2, min_samples_leaf: 10
# Score: 0.7901092581943646, n_estimators: 1000, max_depth: 30, min_samples_split: 2, min_samples_leaf: 30
# Score: 0.7751581368602645, n_estimators: 1000, max_depth: 30, min_samples_split: 2, min_samples_leaf: 100
# Score: 0.7906843013225991, n_estimators: 1000, max_depth: 30, min_samples_split: 5, min_samples_leaf: 10
# Score: 0.7901092581943646, n_estimators: 1000, max_depth: 30, min_samples_split: 5, min_samples_leaf: 30
# Score: 0.7751581368602645, n_estimators: 1000, max_depth: 30, min_samples_split: 5, min_samples_leaf: 100
# Score: 0.7906843013225991, n_estimators: 1000, max_depth: 30, min_samples_split: 10, min_samples_leaf: 10
# Score: 0.7901092581943646, n_estimators: 1000, max_depth: 30, min_samples_split: 10, min_samples_leaf: 30
# Score: 0.7751581368602645, n_estimators: 1000, max_depth: 30, min_samples_split: 10, min_samples_leaf: 100
# Score: 0.7906843013225991, n_estimators: 1000, max_depth: 100, min_samples_split: 2, min_samples_leaf: 10
# Score: 0.7901092581943646, n_estimators: 1000, max_depth: 100, min_samples_split: 2, min_samples_leaf: 30
# Score: 0.7751581368602645, n_estimators: 1000, max_depth: 100, min_samples_split: 2, min_samples_leaf: 100
# Score: 0.7906843013225991, n_estimators: 1000, max_depth: 100, min_samples_split: 5, min_samples_leaf: 10
# Score: 0.7901092581943646, n_estimators: 1000, max_depth: 100, min_samples_split: 5, min_samples_leaf: 30
# Score: 0.7751581368602645, n_estimators: 1000, max_depth: 100, min_samples_split: 5, min_samples_leaf: 100
# Score: 0.7906843013225991, n_estimators: 1000, max_depth: 100, min_samples_split: 10, min_samples_leaf: 10
# Score: 0.7901092581943646, n_estimators: 1000, max_depth: 100, min_samples_split: 10, min_samples_leaf: 30
# Score: 0.7751581368602645, n_estimators: 1000, max_depth: 100, min_samples_split: 10, min_samples_leaf: 100

# %%
params = {"n_estimators": [100, 300, 1000], 
          "learning_rate": [0.1, 0.03, 0.01],
          "max_depth": [10, 30, 100],
          "min_samples_split": [2, 5, 10],
          "min_samples_leaf": [10, 30, 100]}

for (n_estimators, learning_rate, max_depth, min_samples_split, min_samples_leaf) in itertools.product(*params.values()):
    model = GradientBoostingClassifier(n_estimators=n_estimators, learning_rate=learning_rate, max_depth=max_depth, min_samples_split=min_samples_split, min_samples_leaf=min_samples_leaf, random_state=42)
    model.fit(train_x, train_y)
    score = model.score(test_x, test_y)

    print(f"Score: {score}, n_estimators: {n_estimators}, max_depth: {max_depth}, min_samples_split: {min_samples_split}, min_samples_leaf: {min_samples_leaf}")
# Out:
# Score: 0.7981598619896493, n_estimators: 100, max_depth: 10, min_samples_split: 2, min_samples_leaf: 10
# Score: 0.8021851638872916, n_estimators: 100, max_depth: 10, min_samples_split: 2, min_samples_leaf: 30
# Score: 0.8039102932719954, n_estimators: 100, max_depth: 10, min_samples_split: 2, min_samples_leaf: 100
# Score: 0.7981598619896493, n_estimators: 100, max_depth: 10, min_samples_split: 5, min_samples_leaf: 10
# Score: 0.8021851638872916, n_estimators: 100, max_depth: 10, min_samples_split: 5, min_samples_leaf: 30
# Score: 0.8039102932719954, n_estimators: 100, max_depth: 10, min_samples_split: 5, min_samples_leaf: 100
# Score: 0.7981598619896493, n_estimators: 100, max_depth: 10, min_samples_split: 10, min_samples_leaf: 10
# Score: 0.8021851638872916, n_estimators: 100, max_depth: 10, min_samples_split: 10, min_samples_leaf: 30
# Score: 0.8039102932719954, n_estimators: 100, max_depth: 10, min_samples_split: 10, min_samples_leaf: 100
# Score: 0.7849338700402531, n_estimators: 100, max_depth: 30, min_samples_split: 2, min_samples_leaf: 10
# Score: 0.7947096032202415, n_estimators: 100, max_depth: 30, min_samples_split: 2, min_samples_leaf: 30
# Score: 0.7993099482461185, n_estimators: 100, max_depth: 30, min_samples_split: 2, min_samples_leaf: 100
# Score: 0.7849338700402531, n_estimators: 100, max_depth: 30, min_samples_split: 5, min_samples_leaf: 10
# Score: 0.7947096032202415, n_estimators: 100, max_depth: 30, min_samples_split: 5, min_samples_leaf: 30
# Score: 0.7993099482461185, n_estimators: 100, max_depth: 30, min_samples_split: 5, min_samples_leaf: 100
# Score: 0.7849338700402531, n_estimators: 100, max_depth: 30, min_samples_split: 10, min_samples_leaf: 10
# Score: 0.7947096032202415, n_estimators: 100, max_depth: 30, min_samples_split: 10, min_samples_leaf: 30
# Score: 0.7993099482461185, n_estimators: 100, max_depth: 30, min_samples_split: 10, min_samples_leaf: 100
# Score: 0.7883841288096607, n_estimators: 100, max_depth: 100, min_samples_split: 2, min_samples_leaf: 10
# Score: 0.7929844738355377, n_estimators: 100, max_depth: 100, min_samples_split: 2, min_samples_leaf: 30
# Score: 0.8010350776308223, n_estimators: 100, max_depth: 100, min_samples_split: 2, min_samples_leaf: 100
# Score: 0.7883841288096607, n_estimators: 100, max_depth: 100, min_samples_split: 5, min_samples_leaf: 10
# Score: 0.7929844738355377, n_estimators: 100, max_depth: 100, min_samples_split: 5, min_samples_leaf: 30
# Score: 0.8010350776308223, n_estimators: 100, max_depth: 100, min_samples_split: 5, min_samples_leaf: 100
# Score: 0.7883841288096607, n_estimators: 100, max_depth: 100, min_samples_split: 10, min_samples_leaf: 10
# Score: 0.7929844738355377, n_estimators: 100, max_depth: 100, min_samples_split: 10, min_samples_leaf: 30
# Score: 0.8010350776308223, n_estimators: 100, max_depth: 100, min_samples_split: 10, min_samples_leaf: 100
# Score: 0.78953421506613, n_estimators: 100, max_depth: 10, min_samples_split: 2, min_samples_leaf: 10
# Score: 0.7958596894767107, n_estimators: 100, max_depth: 10, min_samples_split: 2, min_samples_leaf: 30
# Score: 0.79700977573318, n_estimators: 100, max_depth: 10, min_samples_split: 2, min_samples_leaf: 100
# Score: 0.78953421506613, n_estimators: 100, max_depth: 10, min_samples_split: 5, min_samples_leaf: 10
# Score: 0.7958596894767107, n_estimators: 100, max_depth: 10, min_samples_split: 5, min_samples_leaf: 30
# Score: 0.79700977573318, n_estimators: 100, max_depth: 10, min_samples_split: 5, min_samples_leaf: 100
# Score: 0.78953421506613, n_estimators: 100, max_depth: 10, min_samples_split: 10, min_samples_leaf: 10
# Score: 0.7958596894767107, n_estimators: 100, max_depth: 10, min_samples_split: 10, min_samples_leaf: 30
# Score: 0.79700977573318, n_estimators: 100, max_depth: 10, min_samples_split: 10, min_samples_leaf: 100
# Score: 0.7866589994249569, n_estimators: 100, max_depth: 30, min_samples_split: 2, min_samples_leaf: 10
# Score: 0.8021851638872916, n_estimators: 100, max_depth: 30, min_samples_split: 2, min_samples_leaf: 30
# Score: 0.8010350776308223, n_estimators: 100, max_depth: 30, min_samples_split: 2, min_samples_leaf: 100
# Score: 0.7866589994249569, n_estimators: 100, max_depth: 30, min_samples_split: 5, min_samples_leaf: 10
# Score: 0.8021851638872916, n_estimators: 100, max_depth: 30, min_samples_split: 5, min_samples_leaf: 30
# Score: 0.8010350776308223, n_estimators: 100, max_depth: 30, min_samples_split: 5, min_samples_leaf: 100
# Score: 0.7866589994249569, n_estimators: 100, max_depth: 30, min_samples_split: 10, min_samples_leaf: 10
# Score: 0.8021851638872916, n_estimators: 100, max_depth: 30, min_samples_split: 10, min_samples_leaf: 30
# Score: 0.8010350776308223, n_estimators: 100, max_depth: 30, min_samples_split: 10, min_samples_leaf: 100
# Score: 0.7837837837837838, n_estimators: 100, max_depth: 100, min_samples_split: 2, min_samples_leaf: 10
# Score: 0.8021851638872916, n_estimators: 100, max_depth: 100, min_samples_split: 2, min_samples_leaf: 30
# Score: 0.8010350776308223, n_estimators: 100, max_depth: 100, min_samples_split: 2, min_samples_leaf: 100
# Score: 0.7837837837837838, n_estimators: 100, max_depth: 100, min_samples_split: 5, min_samples_leaf: 10
# Score: 0.8021851638872916, n_estimators: 100, max_depth: 100, min_samples_split: 5, min_samples_leaf: 30
# Score: 0.8010350776308223, n_estimators: 100, max_depth: 100, min_samples_split: 5, min_samples_leaf: 100
# Score: 0.7837837837837838, n_estimators: 100, max_depth: 100, min_samples_split: 10, min_samples_leaf: 10
# Score: 0.8021851638872916, n_estimators: 100, max_depth: 100, min_samples_split: 10, min_samples_leaf: 30
# Score: 0.8010350776308223, n_estimators: 100, max_depth: 100, min_samples_split: 10, min_samples_leaf: 100
# Score: 0.7843588269120184, n_estimators: 100, max_depth: 10, min_samples_split: 2, min_samples_leaf: 10
# Score: 0.7849338700402531, n_estimators: 100, max_depth: 10, min_samples_split: 2, min_samples_leaf: 30
# Score: 0.7860839562967222, n_estimators: 100, max_depth: 10, min_samples_split: 2, min_samples_leaf: 100
# Score: 0.7843588269120184, n_estimators: 100, max_depth: 10, min_samples_split: 5, min_samples_leaf: 10
# Score: 0.7849338700402531, n_estimators: 100, max_depth: 10, min_samples_split: 5, min_samples_leaf: 30
# Score: 0.7860839562967222, n_estimators: 100, max_depth: 10, min_samples_split: 5, min_samples_leaf: 100
# Score: 0.7843588269120184, n_estimators: 100, max_depth: 10, min_samples_split: 10, min_samples_leaf: 10
# Score: 0.7849338700402531, n_estimators: 100, max_depth: 10, min_samples_split: 10, min_samples_leaf: 30
# Score: 0.7860839562967222, n_estimators: 100, max_depth: 10, min_samples_split: 10, min_samples_leaf: 100
# Score: 0.7837837837837838, n_estimators: 100, max_depth: 30, min_samples_split: 2, min_samples_leaf: 10
# Score: 0.7929844738355377, n_estimators: 100, max_depth: 30, min_samples_split: 2, min_samples_leaf: 30
# Score: 0.7883841288096607, n_estimators: 100, max_depth: 30, min_samples_split: 2, min_samples_leaf: 100
# Score: 0.7837837837837838, n_estimators: 100, max_depth: 30, min_samples_split: 5, min_samples_leaf: 10
# Score: 0.7929844738355377, n_estimators: 100, max_depth: 30, min_samples_split: 5, min_samples_leaf: 30
# Score: 0.7883841288096607, n_estimators: 100, max_depth: 30, min_samples_split: 5, min_samples_leaf: 100
# Score: 0.7837837837837838, n_estimators: 100, max_depth: 30, min_samples_split: 10, min_samples_leaf: 10
# Score: 0.7929844738355377, n_estimators: 100, max_depth: 30, min_samples_split: 10, min_samples_leaf: 30
# Score: 0.7883841288096607, n_estimators: 100, max_depth: 30, min_samples_split: 10, min_samples_leaf: 100
# Score: 0.7837837837837838, n_estimators: 100, max_depth: 100, min_samples_split: 2, min_samples_leaf: 10
# Score: 0.7929844738355377, n_estimators: 100, max_depth: 100, min_samples_split: 2, min_samples_leaf: 30
# Score: 0.7883841288096607, n_estimators: 100, max_depth: 100, min_samples_split: 2, min_samples_leaf: 100
# Score: 0.7837837837837838, n_estimators: 100, max_depth: 100, min_samples_split: 5, min_samples_leaf: 10
# Score: 0.7929844738355377, n_estimators: 100, max_depth: 100, min_samples_split: 5, min_samples_leaf: 30
# Score: 0.7883841288096607, n_estimators: 100, max_depth: 100, min_samples_split: 5, min_samples_leaf: 100
# Score: 0.7837837837837838, n_estimators: 100, max_depth: 100, min_samples_split: 10, min_samples_leaf: 10
# Score: 0.7929844738355377, n_estimators: 100, max_depth: 100, min_samples_split: 10, min_samples_leaf: 30
# Score: 0.7883841288096607, n_estimators: 100, max_depth: 100, min_samples_split: 10, min_samples_leaf: 100
# Score: 0.7912593444508338, n_estimators: 300, max_depth: 10, min_samples_split: 2, min_samples_leaf: 10
# Score: 0.7889591719378953, n_estimators: 300, max_depth: 10, min_samples_split: 2, min_samples_leaf: 30
# Score: 0.7947096032202415, n_estimators: 300, max_depth: 10, min_samples_split: 2, min_samples_leaf: 100
# Score: 0.7912593444508338, n_estimators: 300, max_depth: 10, min_samples_split: 5, min_samples_leaf: 10
# Score: 0.7889591719378953, n_estimators: 300, max_depth: 10, min_samples_split: 5, min_samples_leaf: 30
# Score: 0.7947096032202415, n_estimators: 300, max_depth: 10, min_samples_split: 5, min_samples_leaf: 100
# Score: 0.7912593444508338, n_estimators: 300, max_depth: 10, min_samples_split: 10, min_samples_leaf: 10
# Score: 0.7889591719378953, n_estimators: 300, max_depth: 10, min_samples_split: 10, min_samples_leaf: 30
# Score: 0.7947096032202415, n_estimators: 300, max_depth: 10, min_samples_split: 10, min_samples_leaf: 100
# Score: 0.7878090856814262, n_estimators: 300, max_depth: 30, min_samples_split: 2, min_samples_leaf: 10
# Score: 0.7924094307073031, n_estimators: 300, max_depth: 30, min_samples_split: 2, min_samples_leaf: 30
# Score: 0.7941345600920069, n_estimators: 300, max_depth: 30, min_samples_split: 2, min_samples_leaf: 100
# Score: 0.7878090856814262, n_estimators: 300, max_depth: 30, min_samples_split: 5, min_samples_leaf: 10
# Score: 0.7924094307073031, n_estimators: 300, max_depth: 30, min_samples_split: 5, min_samples_leaf: 30
# Score: 0.7941345600920069, n_estimators: 300, max_depth: 30, min_samples_split: 5, min_samples_leaf: 100
# Score: 0.7878090856814262, n_estimators: 300, max_depth: 30, min_samples_split: 10, min_samples_leaf: 10
# Score: 0.7924094307073031, n_estimators: 300, max_depth: 30, min_samples_split: 10, min_samples_leaf: 30
# Score: 0.7941345600920069, n_estimators: 300, max_depth: 30, min_samples_split: 10, min_samples_leaf: 100
# Score: 0.7883841288096607, n_estimators: 300, max_depth: 100, min_samples_split: 2, min_samples_leaf: 10
# Score: 0.7964347326049454, n_estimators: 300, max_depth: 100, min_samples_split: 2, min_samples_leaf: 30
# Score: 0.7901092581943646, n_estimators: 300, max_depth: 100, min_samples_split: 2, min_samples_leaf: 100
# Score: 0.7883841288096607, n_estimators: 300, max_depth: 100, min_samples_split: 5, min_samples_leaf: 10
# Score: 0.7964347326049454, n_estimators: 300, max_depth: 100, min_samples_split: 5, min_samples_leaf: 30
# Score: 0.7901092581943646, n_estimators: 300, max_depth: 100, min_samples_split: 5, min_samples_leaf: 100
# Score: 0.7883841288096607, n_estimators: 300, max_depth: 100, min_samples_split: 10, min_samples_leaf: 10
# Score: 0.7964347326049454, n_estimators: 300, max_depth: 100, min_samples_split: 10, min_samples_leaf: 30
# Score: 0.7901092581943646, n_estimators: 300, max_depth: 100, min_samples_split: 10, min_samples_leaf: 100
# Score: 0.7964347326049454, n_estimators: 300, max_depth: 10, min_samples_split: 2, min_samples_leaf: 10
# Score: 0.8010350776308223, n_estimators: 300, max_depth: 10, min_samples_split: 2, min_samples_leaf: 30
# Score: 0.8056354226566993, n_estimators: 300, max_depth: 10, min_samples_split: 2, min_samples_leaf: 100
# Score: 0.7964347326049454, n_estimators: 300, max_depth: 10, min_samples_split: 5, min_samples_leaf: 10
# Score: 0.8010350776308223, n_estimators: 300, max_depth: 10, min_samples_split: 5, min_samples_leaf: 30
# Score: 0.8056354226566993, n_estimators: 300, max_depth: 10, min_samples_split: 5, min_samples_leaf: 100
# Score: 0.7964347326049454, n_estimators: 300, max_depth: 10, min_samples_split: 10, min_samples_leaf: 10
# Score: 0.8010350776308223, n_estimators: 300, max_depth: 10, min_samples_split: 10, min_samples_leaf: 30
# Score: 0.8056354226566993, n_estimators: 300, max_depth: 10, min_samples_split: 10, min_samples_leaf: 100
# Score: 0.7866589994249569, n_estimators: 300, max_depth: 30, min_samples_split: 2, min_samples_leaf: 10
# Score: 0.8010350776308223, n_estimators: 300, max_depth: 30, min_samples_split: 2, min_samples_leaf: 30
# Score: 0.8033352501437608, n_estimators: 300, max_depth: 30, min_samples_split: 2, min_samples_leaf: 100
# Score: 0.7866589994249569, n_estimators: 300, max_depth: 30, min_samples_split: 5, min_samples_leaf: 10
# Score: 0.8010350776308223, n_estimators: 300, max_depth: 30, min_samples_split: 5, min_samples_leaf: 30
# Score: 0.8033352501437608, n_estimators: 300, max_depth: 30, min_samples_split: 5, min_samples_leaf: 100
# Score: 0.7866589994249569, n_estimators: 300, max_depth: 30, min_samples_split: 10, min_samples_leaf: 10
# Score: 0.8010350776308223, n_estimators: 300, max_depth: 30, min_samples_split: 10, min_samples_leaf: 30
# Score: 0.8033352501437608, n_estimators: 300, max_depth: 30, min_samples_split: 10, min_samples_leaf: 100
# Score: 0.7912593444508338, n_estimators: 300, max_depth: 100, min_samples_split: 2, min_samples_leaf: 10
# Score: 0.7952846463484762, n_estimators: 300, max_depth: 100, min_samples_split: 2, min_samples_leaf: 30
# Score: 0.8004600345025877, n_estimators: 300, max_depth: 100, min_samples_split: 2, min_samples_leaf: 100
# Score: 0.7912593444508338, n_estimators: 300, max_depth: 100, min_samples_split: 5, min_samples_leaf: 10
# Score: 0.7952846463484762, n_estimators: 300, max_depth: 100, min_samples_split: 5, min_samples_leaf: 30
# Score: 0.8004600345025877, n_estimators: 300, max_depth: 100, min_samples_split: 5, min_samples_leaf: 100
# Score: 0.7912593444508338, n_estimators: 300, max_depth: 100, min_samples_split: 10, min_samples_leaf: 10
# Score: 0.7952846463484762, n_estimators: 300, max_depth: 100, min_samples_split: 10, min_samples_leaf: 30
# Score: 0.8004600345025877, n_estimators: 300, max_depth: 100, min_samples_split: 10, min_samples_leaf: 100
# Score: 0.7941345600920069, n_estimators: 300, max_depth: 10, min_samples_split: 2, min_samples_leaf: 10
# Score: 0.7975848188614146, n_estimators: 300, max_depth: 10, min_samples_split: 2, min_samples_leaf: 30
# Score: 0.7981598619896493, n_estimators: 300, max_depth: 10, min_samples_split: 2, min_samples_leaf: 100
# Score: 0.7941345600920069, n_estimators: 300, max_depth: 10, min_samples_split: 5, min_samples_leaf: 10
# Score: 0.7975848188614146, n_estimators: 300, max_depth: 10, min_samples_split: 5, min_samples_leaf: 30
# Score: 0.7981598619896493, n_estimators: 300, max_depth: 10, min_samples_split: 5, min_samples_leaf: 100
# Score: 0.7941345600920069, n_estimators: 300, max_depth: 10, min_samples_split: 10, min_samples_leaf: 10
# Score: 0.7975848188614146, n_estimators: 300, max_depth: 10, min_samples_split: 10, min_samples_leaf: 30
# Score: 0.7981598619896493, n_estimators: 300, max_depth: 10, min_samples_split: 10, min_samples_leaf: 100
# Score: 0.7866589994249569, n_estimators: 300, max_depth: 30, min_samples_split: 2, min_samples_leaf: 10
# Score: 0.8004600345025877, n_estimators: 300, max_depth: 30, min_samples_split: 2, min_samples_leaf: 30
# Score: 0.7998849913743531, n_estimators: 300, max_depth: 30, min_samples_split: 2, min_samples_leaf: 100
# Score: 0.7866589994249569, n_estimators: 300, max_depth: 30, min_samples_split: 5, min_samples_leaf: 10
# Score: 0.8004600345025877, n_estimators: 300, max_depth: 30, min_samples_split: 5, min_samples_leaf: 30
# Score: 0.7998849913743531, n_estimators: 300, max_depth: 30, min_samples_split: 5, min_samples_leaf: 100
# Score: 0.7866589994249569, n_estimators: 300, max_depth: 30, min_samples_split: 10, min_samples_leaf: 10
# Score: 0.8004600345025877, n_estimators: 300, max_depth: 30, min_samples_split: 10, min_samples_leaf: 30
# Score: 0.7998849913743531, n_estimators: 300, max_depth: 30, min_samples_split: 10, min_samples_leaf: 100
# Score: 0.7883841288096607, n_estimators: 300, max_depth: 100, min_samples_split: 2, min_samples_leaf: 10
# Score: 0.8004600345025877, n_estimators: 300, max_depth: 100, min_samples_split: 2, min_samples_leaf: 30
# Score: 0.7998849913743531, n_estimators: 300, max_depth: 100, min_samples_split: 2, min_samples_leaf: 100
# Score: 0.7883841288096607, n_estimators: 300, max_depth: 100, min_samples_split: 5, min_samples_leaf: 10
# Score: 0.8004600345025877, n_estimators: 300, max_depth: 100, min_samples_split: 5, min_samples_leaf: 30
# Score: 0.7998849913743531, n_estimators: 300, max_depth: 100, min_samples_split: 5, min_samples_leaf: 100
# Score: 0.7883841288096607, n_estimators: 300, max_depth: 100, min_samples_split: 10, min_samples_leaf: 10
# Score: 0.8004600345025877, n_estimators: 300, max_depth: 100, min_samples_split: 10, min_samples_leaf: 30
# Score: 0.7998849913743531, n_estimators: 300, max_depth: 100, min_samples_split: 10, min_samples_leaf: 100
# Score: 0.7901092581943646, n_estimators: 1000, max_depth: 10, min_samples_split: 2, min_samples_leaf: 10
# Score: 0.7763082231167338, n_estimators: 1000, max_depth: 10, min_samples_split: 2, min_samples_leaf: 30
# Score: 0.7866589994249569, n_estimators: 1000, max_depth: 10, min_samples_split: 2, min_samples_leaf: 100
# Score: 0.7901092581943646, n_estimators: 1000, max_depth: 10, min_samples_split: 5, min_samples_leaf: 10
# Score: 0.7763082231167338, n_estimators: 1000, max_depth: 10, min_samples_split: 5, min_samples_leaf: 30
# Score: 0.7866589994249569, n_estimators: 1000, max_depth: 10, min_samples_split: 5, min_samples_leaf: 100
# Score: 0.7901092581943646, n_estimators: 1000, max_depth: 10, min_samples_split: 10, min_samples_leaf: 10
# Score: 0.7763082231167338, n_estimators: 1000, max_depth: 10, min_samples_split: 10, min_samples_leaf: 30
# Score: 0.7866589994249569, n_estimators: 1000, max_depth: 10, min_samples_split: 10, min_samples_leaf: 100
# Score: 0.7855089131684876, n_estimators: 1000, max_depth: 30, min_samples_split: 2, min_samples_leaf: 10
# Score: 0.7797584818861415, n_estimators: 1000, max_depth: 30, min_samples_split: 2, min_samples_leaf: 30

# %%
from joblib import dump

# train final model and save
model = GradientBoostingClassifier(n_estimators=300, learning_rate=0.03, max_depth=10, min_samples_split=2, min_samples_leaf=100, random_state=42)
model.fit(np.concatenate((train_x, test_x), axis=0), np.concatenate((train_y, test_y)))

dump(model, "GradientBoostingClassifier.joblib")
# Out:
# ['GradientBoostingClassifier.joblib']
